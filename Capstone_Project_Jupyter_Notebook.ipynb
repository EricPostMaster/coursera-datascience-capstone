# %% [markdown]
# <a href="https://colab.research.google.com/github/EricPostMaster/coursera-datascience-capstone/blob/master/Capstone_Project_Jupyter_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project Notebook
#        Created by Eric Sims

# %% [markdown]
# ## Methodology

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import csv
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Import Home Value Data
# I downloaded and cleaned Zillow Home Value Index data for all of North Carolina and segmented out only the largest 150 zip codes in the state, figureing that the great majority of people live in those areas.

# %%
df_data_1 = pd.read_csv('/content/NC-ZHVI.csv')
df_data_1.head()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
#    ZipCode          City  SizeRank  ...  2018Weight    2019  2019Weight
# 0    28269     Charlotte         1  ...           4  222079           5
# 1    28277     Charlotte         2  ...           4  366603           5
# 2    28027       Concord         3  ...           4  250122           5
# 3    27587   Wake Forest         4  ...           4  330524           5
# 4    28078  Huntersville         5  ...           4  318790           5
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Calculate the percent growth in home value since 2015 by zip code:

# %%
percent_growth = round(100*((df_data_1["2019"] - df_data_1["2015"])/df_data_1["2015"]),2)

percent_growth[0:5]
# Out:
# 0    37.80
# 1    21.83
# 2    27.18
# 3    15.74
# 4    21.76
# dtype: float64

# %% [markdown]
# Okay, so that is the growth from 2015-2019.

# %% [markdown]
# ### Add to dataframe

# %%
df_data_1["Growth"] = percent_growth
df_data_1.head()
# Out:
#    ZipCode          City  SizeRank  ...    2019  2019Weight  Growth
# 0    28269     Charlotte         1  ...  222079           5   37.80
# 1    28277     Charlotte         2  ...  366603           5   21.83
# 2    28027       Concord         3  ...  250122           5   27.18
# 3    27587   Wake Forest         4  ...  330524           5   15.74
# 4    28078  Huntersville         5  ...  318790           5   21.76
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Look for outliers to focus on

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax = sns.barplot(x="ZipCode", y="Growth", data=df_data_1, label="Zip Code")
temp = ax.xaxis.get_ticklabels()
temp = list(set(temp) - set(temp[::10]))
for label in temp:
    label.set_visible(False)
ax.legend(loc="upper left")

# %% [markdown]
# From this we can see that almost everywhere has seen 15%-30% growth over the past 5 years.  There are 10-15 places that have seen over 40% growth.  We want to focus on them!

# %% [markdown]
# ### Separate out the top values to focus on

# %%
df_top_charlotte = df_data_1.sort_values(by='Growth', ascending=False)[0:5]
df_top_charlotte
# Out:
#      ZipCode       City  SizeRank  ...    2019  2019Weight  Growth
# 81     28208  Charlotte        82  ...  148220           5   78.37
# 102    28052   Gastonia       103  ...  117987           5   65.36
# 131    28217  Charlotte       132  ...  155477           5   60.37
# 68     28212  Charlotte        69  ...  187153           5   54.47
# 19     28216  Charlotte        20  ...  185619           5   52.08
#
# [5 rows x 14 columns]

# %% [markdown]
# So, it looks like four out of the top 5 growing zip codes are located in the Charlotte, NC area.  Let's focus on them.  Let's filter out that Gastonia zip code:

# %%
condition = df_top_charlotte["City"] == "Charlotte"

df_top_charlotte = df_top_charlotte[condition]

df_top_charlotte = df_top_charlotte.rename(columns={"ZipCode": "zipcode"})
df_top_charlotte
# Out:
#      zipcode       City  SizeRank  ...    2019  2019Weight  Growth
# 81     28208  Charlotte        82  ...  148220           5   78.37
# 131    28217  Charlotte       132  ...  155477           5   60.37
# 68     28212  Charlotte        69  ...  187153           5   54.47
# 19     28216  Charlotte        20  ...  185619           5   52.08
#
# [4 rows x 14 columns]

# %% [markdown]
# ### Map the zip codes using Folium

# %%
# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.18.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.11.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.8)

# %%
charlotte_map = folium.Map(location=[35.2271, -80.8431], zoom_start=10)

charlotte_geo = '/content/meckzipcodes2.geojson'

# %% [markdown]
# Lesson learned here!  Make sure that the data type of your key_on column matches the data type of the column it is connected to in your dataframe!  My zip codes were strings in the geojson file, and that took a while to fix.

# %%
charlotte_map = folium.Map(location=[35.2271, -80.8431], zoom_start=11)

folium.Choropleth(
    geo_data=charlotte_geo,
    data=df_top_charlotte,
    columns=['zipcode', 'Growth'],
    key_on='feature.properties.zipcode',
    fill_color='YlOrRd', 
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Growth in Charlotte",
    highlight=True
).add_to(charlotte_map)

charlotte_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Query data from the Foursquare API
# First we will save the client query info to Python objects:

# %%
# @hidden_cell
client_id = '4O22F2EMXXKWC2BE3S40GIROQFI4BC232YL0BC1PQXNP4I0T'
client_secret = 'QVE25XYPVATCJTGVR31B3CT3K310BGJFA4VBKTPSHGLYMRT5'
radius = 13680 #This is an 8.5-mile radius to stay outside of central Charlotte
radius2 = 5632 #3.5-mile radius
venue_count = 150
section = 'food'
version = '20200331'
charlotte_lat = 35.320981
charlotte_lon = -80.944489
charlotte_lat2 = 35.164533
charlotte_lon2 = -80.936224

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&section={}'.format(
    client_id, 
    client_secret, 
    version, 
    charlotte_lat, 
    charlotte_lon, 
    radius, 
    venue_count,
    section)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=4O22F2EMXXKWC2BE3S40GIROQFI4BC232YL0BC1PQXNP4I0T&client_secret=QVE25XYPVATCJTGVR31B3CT3K310BGJFA4VBKTPSHGLYMRT5&v=20200331&ll=35.320981,-80.944489&radius=13680&limit=200&section=food'

# %%
url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&section={}'.format(
    client_id, 
    client_secret, 
    version, 
    charlotte_lat2, 
    charlotte_lon2, 
    radius2, 
    venue_count,
    section)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=4O22F2EMXXKWC2BE3S40GIROQFI4BC232YL0BC1PQXNP4I0T&client_secret=QVE25XYPVATCJTGVR31B3CT3K310BGJFA4VBKTPSHGLYMRT5&v=20200331&ll=35.164533,-80.936224&radius=5632&limit=150&section=food'

# %%
import requests
from pandas.io.json import json_normalize

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e840c949388d700281d461e'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b5de371f964a5203d7229e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4b5de371f964a5203d7229e3',
#        'location': {'address': '9731 Callabridge Ct',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 654,
#         'formattedAddress': ['9731 Callabridge Ct',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.326858,
#           'lng': -80.9447592}],
#         'lat': 35.326858,
#         'lng': -80.9447592,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Chick-fil-A',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b2cd765f964a520cdc924e3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'primary': True,
#          'shortName': 'Breakfast'}],
#        'delivery': {'id': '1471704',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/shuffletown-drive-in-10220-rozzelles-ferry-road-charlotte/1471704?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1471704'},
#        'id': '4b2cd765f964a520cdc924e3',
#        'location': {'address': '10220 Rozzelles Ferry Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'Mt Holly Huntersville Rd',
#         'distance': 769,
#         'formattedAddress': ['10220 Rozzelles Ferry Rd (Mt Holly Huntersville Rd)',
#          'Charlotte, NC 28214',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.32162976136568,
#           'lng': -80.95292197508289}],
#         'lat': 35.32162976136568,
#         'lng': -80.95292197508289,
#         'postalCode': '28214',
#         'state': 'NC'},
#        'name': 'Shuffletown Drive-in',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-53134fbd498e4b85c86217b3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'primary': True,
#          'shortName': 'Southern / Soul'}],
#        'delivery': {'id': '1321807',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/heirloom-restaurant-8470-bellhaven-boulevard-charlotte/1321807?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1321807'},
#        'id': '53134fbd498e4b85c86217b3',
#        'location': {'address': '8470 Belhaven Boulevard, Charlotte, NC 28216',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 1884,
#         'formattedAddress': ['8470 Belhaven Boulevard, Charlotte, NC 28216',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.305047393843466,
#           'lng': -80.93748603891804}],
#         'lat': 35.305047393843466,
#         'lng': -80.93748603891804,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Heirloom',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5d2e2c0699a98b00232bd8d9-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '5d2e2c0699a98b00232bd8d9',
#        'location': {'address': '3811 Corning Place',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 613,
#         'formattedAddress': ['3811 Corning Place',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.326412,
#           'lng': -80.94336}],
#         'lat': 35.326412,
#         'lng': -80.94336,
#         'neighborhood': 'Mountain Island',
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': "Freddy's Frozen Custard & Steakburgers",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '570541560'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b2e9f5df964a520c5e324e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'delivery': {'id': '1470474',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/tonys-pizza-9548-mount-holly-huntersville-road-huntersville/1470474?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470474'},
#        'id': '4b2e9f5df964a520c5e324e3',
#        'location': {'address': '9548 Mt. Holly-Huntersville Rd.',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'Vance Rd',
#         'distance': 8029,
#         'formattedAddress': ['9548 Mt. Holly-Huntersville Rd. (Vance Rd)',
#          'Charlotte, NC 28078',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.35731213009876,
#           'lng': -80.86810527954101}],
#         'lat': 35.35731213009876,
#         'lng': -80.86810527954101,
#         'postalCode': '28078',
#         'state': 'NC'},
#        'name': "Tony's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b6da818f964a520d5832ce3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4b6da818f964a520d5832ce3',
#        'location': {'address': '8411 Northlake Commons Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8609,
#         'formattedAddress': ['8411 Northlake Commons Blvd',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.3497317,
#           'lng': -80.8564731}],
#         'lat': 35.3497317,
#         'lng': -80.8564731,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Chick-fil-A',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-530d77f111d2d69d19423d70-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'delivery': {'id': '1320294',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/stockyard-restaurant-4925-rozzelles-ferry-road-charlotte/1320294?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1320294'},
#        'id': '530d77f111d2d69d19423d70',
#        'location': {'address': '4925 Rozzelles Ferry Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 7129,
#         'formattedAddress': ['4925 Rozzelles Ferry Rd',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.273696192295915,
#           'lng': -80.89156326552437}],
#         'lat': 35.273696192295915,
#         'lng': -80.89156326552437,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Stockyard Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4d56b813e7f1a1cdbd2a0aa5-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'delivery': {'id': '1313174',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/south-21-family-restaurant-6116-brookshire-boulevard-charlotte/1313174?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1313174'},
#        'id': '4d56b813e7f1a1cdbd2a0aa5',
#        'location': {'address': '6116 Brookshire Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5229,
#         'formattedAddress': ['6116 Brookshire Blvd',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.28618263143489,
#           'lng': -80.90582510748393}],
#         'lat': 35.28618263143489,
#         'lng': -80.90582510748393,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'South 21',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4c0ea8082466a593a46a7921-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'delivery': {'id': '1970287',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/five-guys-9749-northlake-centre-pkwy-charlotte/1970287?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1970287'},
#        'id': '4c0ea8082466a593a46a7921',
#        'location': {'address': '9749 Northlake Centre Parkway, Suite E',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8364,
#         'formattedAddress': ['9749 Northlake Centre Parkway, Suite E',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.34811982692359,
#           'lng': -80.85860043663361}],
#         'lat': 35.34811982692359,
#         'lng': -80.85860043663361,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Five Guys',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-51b11057498e8aadb3da10a5-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'id': '51b11057498e8aadb3da10a5',
#        'location': {'address': '130 W Charlotte Ave',
#         'cc': 'US',
#         'city': 'Mount Holly',
#         'country': 'United States',
#         'distance': 7095,
#         'formattedAddress': ['130 W Charlotte Ave',
#          'Mount Holly, NC 28120',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.29834241803569,
#           'lng': -81.01750015013506}],
#         'lat': 35.29834241803569,
#         'lng': -81.01750015013506,
#         'postalCode': '28120',
#         'state': 'NC'},
#        'name': 'Chicken King',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4c090521a1b32d7f73e296f0-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'delivery': {'id': '1313130',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/circle-g-restaurant-4818-rozzelles-ferry-road-charlotte/1313130?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1313130'},
#        'id': '4c090521a1b32d7f73e296f0',
#        'location': {'address': '4818 Rozzelles Ferry Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 7312,
#         'formattedAddress': ['4818 Rozzelles Ferry Rd',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.27279448105521,
#           'lng': -80.88979330954973}],
#         'lat': 35.27279448105521,
#         'lng': -80.88979330954973,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Circle G Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b8eebdcf964a520d43e33e3-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'id': '4b8eebdcf964a520d43e33e3',
#        'location': {'address': '9230 Beatties Ford Rd',
#         'cc': 'US',
#         'city': 'Huntersville',
#         'country': 'United States',
#         'crossStreet': 'at Mt Holly-Huntersville Rd',
#         'distance': 6127,
#         'formattedAddress': ['9230 Beatties Ford Rd (at Mt Holly-Huntersville Rd)',
#          'Huntersville, NC 28078',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.35143303700765,
#           'lng': -80.88827890543683}],
#         'lat': 35.35143303700765,
#         'lng': -80.88827890543683,
#         'postalCode': '28078',
#         'state': 'NC'},
#        'name': "Lancaster's BBQ",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4bf87c7f5ec320a154e788d3-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'delivery': {'id': '384869',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/pf-changs-10325-perimeter-pkwy-charlotte/384869?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=384869'},
#        'id': '4bf87c7f5ec320a154e788d3',
#        'location': {'address': '10325 Perimeter Pkwy',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'at W T Harris Blvd',
#         'distance': 8846,
#         'formattedAddress': ['10325 Perimeter Pkwy (at W T Harris Blvd)',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.3488083,
#           'lng': -80.853242}],
#         'lat': 35.3488083,
#         'lng': -80.853242,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': "P.F. Chang's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-55135b32498e5bdc615ab75f-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '55135b32498e5bdc615ab75f',
#        'location': {'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 9133,
#         'formattedAddress': ['Charlotte, NC', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.35219241509937,
#           'lng': -80.85147142447552}],
#         'lat': 35.35219241509937,
#         'lng': -80.85147142447552,
#         'state': 'NC'},
#        'name': 'Firebirds',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4c6042de54ac0f47891ab521-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'delivery': {'id': '1309247',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/azteca-mexican-restaurant-7340-smith-corners-boulevard-charlotte/1309247?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1309247'},
#        'id': '4c6042de54ac0f47891ab521',
#        'location': {'address': '7340 Smith Corners Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 9917,
#         'formattedAddress': ['7340 Smith Corners Blvd',
#          'Charlotte, NC 28269',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.35120901314846,
#           'lng': -80.84175302034036}],
#         'lat': 35.35120901314846,
#         'lng': -80.84175302034036,
#         'postalCode': '28269',
#         'state': 'NC'},
#        'name': 'Azteca Mexican Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-57cf2bcd498eafbf8cd5a095-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '57cf2bcd498eafbf8cd5a095',
#        'location': {'address': '6801 Northlake Mall Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 9181,
#         'formattedAddress': ['6801 Northlake Mall Dr',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.352422999999995,
#           'lng': -80.85101999999999}],
#         'lat': 35.352422999999995,
#         'lng': -80.85101999999999,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Firebirds Wood Fired Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b12a730f964a520e28b23e3-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'delivery': {'id': '1247757',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/panera-bread-9309-center-lake-dr-charlotte/1247757?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1247757'},
#        'id': '4b12a730f964a520e28b23e3',
#        'location': {'address': '9309 Center Lake Dr Ste 100',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8781,
#         'formattedAddress': ['9309 Center Lake Dr Ste 100',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.3497181,
#           'lng': -80.854428}],
#         'lat': 35.3497181,
#         'lng': -80.854428,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'Panera Bread',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-53cd66c0498ed3c20983f514-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'id': '53cd66c0498ed3c20983f514',
#        'location': {'address': '403 E Catawba St Ste 200',
#         'cc': 'US',
#         'city': 'Belmont',
#         'country': 'United States',
#         'crossStreet': 'N 3rd St',
#         'distance': 11566,
#         'formattedAddress': ['403 E Catawba St Ste 200 (N 3rd St)',
#          'Belmont, NC 28012',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.243,
#           'lng': -81.0286}],
#         'lat': 35.243,
#         'lng': -81.0286,
#         'postalCode': '28012',
#         'state': 'NC'},
#        'name': 'Peace -N- Hominy Q Shack',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '100919746'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4c4f432279ffe21ea0485b1a-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4c4f432279ffe21ea0485b1a',
#        'location': {'address': '2540 Little Rock Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8511,
#         'formattedAddress': ['2540 Little Rock Rd',
#          'Charlotte, NC 28214',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.24469,
#           'lng': -80.9382}],
#         'lat': 35.24469,
#         'lng': -80.9382,
#         'postalCode': '28214',
#         'state': 'NC'},
#        'name': 'Showmars',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4c75b8a03adda143ef4908af-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '4c75b8a03adda143ef4908af',
#        'location': {'address': '645 Park St',
#         'cc': 'US',
#         'city': 'Belmont',
#         'country': 'United States',
#         'distance': 10593,
#         'formattedAddress': ['645 Park St',
#          'Belmont, NC 28012',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.25430299308606,
#           'lng': -81.02767466504838}],
#         'lat': 35.25430299308606,
#         'lng': -81.02767466504838,
#         'postalCode': '28012',
#         'state': 'NC'},
#        'name': 'Sake Express',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-511ab0b4e4b0e23900125339-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14c941735',
#          'name': 'Wings Joint',
#          'pluralName': 'Wings Joints',
#          'primary': True,
#          'shortName': 'Wings'}],
#        'id': '511ab0b4e4b0e23900125339',
#        'location': {'address': '9711 Northlake Centre Pkwy',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8328,
#         'formattedAddress': ['9711 Northlake Centre Pkwy',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.34753867956286,
#           'lng': -80.85875139292796}],
#         'lat': 35.34753867956286,
#         'lng': -80.85875139292796,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': 'East Coast Wings & Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-51b8d030498e698ac58ef113-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'delivery': {'id': '466156',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/jersey-mikes-10125-perimeter-pkwy-ste-c-charlotte/466156?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=466156'},
#        'id': '51b8d030498e698ac58ef113',
#        'location': {'address': '10125 Perimeter Parkway, Ste. C',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8798,
#         'formattedAddress': ['10125 Perimeter Parkway, Ste. C',
#          'Charlotte, NC 28216-2475',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.34649,
#           'lng': -80.852794}],
#         'lat': 35.34649,
#         'lng': -80.852794,
#         'postalCode': '28216-2475',
#         'state': 'NC'},
#        'name': "Jersey Mike's Subs",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5456f3f3498ed7a6b8eb04f4-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'primary': True,
#          'shortName': 'Deli / Bodega'}],
#        'delivery': {'id': '1318376',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/rhino-market--deli-1500-west-morehead-street-charlotte/1318376?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1318376'},
#        'id': '5456f3f3498ed7a6b8eb04f4',
#        'location': {'address': '1500 W Morehead St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 12422,
#         'formattedAddress': ['1500 W Morehead St',
#          'Charlotte, NC 28208',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.2297345226206,
#           'lng': -80.86579464304569}],
#         'lat': 35.2297345226206,
#         'lng': -80.86579464304569,
#         'postalCode': '28208',
#         'state': 'NC'},
#        'name': 'Rhino Market and Deli',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4ccc8582063a721e773f8f9a-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'delivery': {'id': '1534811',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/pinkys-westside-grill-1600-w-morehead-st-charlotte/1534811?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1534811'},
#        'id': '4ccc8582063a721e773f8f9a',
#        'location': {'address': '1600 W Morehead St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 12398,
#         'formattedAddress': ['1600 W Morehead St',
#          'Charlotte, NC 28208',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22916296113382,
#           'lng': -80.86726980280673}],
#         'lat': 35.22916296113382,
#         'lng': -80.86726980280673,
#         'postalCode': '28208',
#         'state': 'NC'},
#        'name': "Pinky's Westside Grill",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4bc515065935c9b61886a5d2-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'delivery': {'id': '1313784',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/miguels-restaurants-4252-business-center-drive-charlotte/1313784?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1313784'},
#        'id': '4bc515065935c9b61886a5d2',
#        'location': {'address': '4252 Business Center Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8798,
#         'formattedAddress': ['4252 Business Center Dr',
#          'Charlotte, NC 28214',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.242033155517014,
#           'lng': -80.93974428244663}],
#         'lat': 35.242033155517014,
#         'lng': -80.93974428244663,
#         'postalCode': '28214',
#         'state': 'NC'},
#        'name': "Miguel's Restaurant",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-547f55ca498e5bb8a8c5077e-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '547f55ca498e5bb8a8c5077e',
#        'location': {'cc': 'US',
#         'city': 'Huntersville',
#         'country': 'United States',
#         'distance': 12343,
#         'formattedAddress': ['Huntersville, NC', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.40849394943094,
#           'lng': -80.8609796683206}],
#         'lat': 35.40849394943094,
#         'lng': -80.8609796683206,
#         'state': 'NC'},
#        'name': 'Phở Ginseng',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-543d79d8498e299b60ae511a-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '543d79d8498e299b60ae511a',
#        'location': {'cc': 'US',
#         'city': 'Mount Holly',
#         'country': 'United States',
#         'distance': 6989,
#         'formattedAddress': ['Mount Holly, NC', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.29820993673372,
#           'lng': -81.0161893962721}],
#         'lat': 35.29820993673372,
#         'lng': -81.0161893962721,
#         'state': 'NC'},
#        'name': 'Catawba Coffee Co',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b21405cf964a520033924e3-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'delivery': {'id': '493466',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/little-village-grill-710-w-trade-st-ste-g-charlotte/493466?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=493466'},
#        'id': '4b21405cf964a520033924e3',
#        'location': {'address': '710 W Trade St Ste G',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'btwn Graham & Cedar',
#         'distance': 13180,
#         'formattedAddress': ['710 W Trade St Ste G (btwn Graham & Cedar)',
#          'Charlotte, NC 28202',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.23202294271822,
#           'lng': -80.84876686048078}],
#         'lat': 35.23202294271822,
#         'lng': -80.84876686048078,
#         'postalCode': '28202',
#         'state': 'NC'},
#        'name': 'Little Village Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4c38e97ba52cb713327e5f26-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'delivery': {'id': '1309920',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/davincis-pizza-8511-davis-lake-parkway-charlotte/1309920?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1309920'},
#        'id': '4c38e97ba52cb713327e5f26',
#        'location': {'address': '8511 Davis Lake Pkwy',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'WT Harris Blvd',
#         'distance': 11993,
#         'formattedAddress': ['8511 Davis Lake Pkwy (WT Harris Blvd)',
#          'Charlotte, NC 28269',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.33503009501761,
#           'lng': -80.81356097242214}],
#         'lat': 35.33503009501761,
#         'lng': -80.81356097242214,
#         'postalCode': '28269',
#         'state': 'NC'},
#        'name': "Davinci's  Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-592098bdc62b4920e25d2e3a-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'delivery': {'id': '1318816',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/cuzzos-cuisine-3418-tuckaseegee-road-charlotte/1318816?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1318816'},
#        'id': '592098bdc62b4920e25d2e3a',
#        'location': {'address': '3418 Tuckaseegee Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'Fern Ave',
#         'distance': 10068,
#         'formattedAddress': ['3418 Tuckaseegee Rd (Fern Ave)',
#          'Charlotte, NC 28208',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.24521603721252,
#           'lng': -80.88396549224854}],
#         'lat': 35.24521603721252,
#         'lng': -80.88396549224854,
#         'postalCode': '28208',
#         'state': 'NC'},
#        'name': "Cuzzo's Cuisine (Brick & Mortar)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b4f5122f964a520080127e3-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'id': '4b4f5122f964a520080127e3',
#        'location': {'address': '9335 Center Lake Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 8634,
#         'formattedAddress': ['9335 Center Lake Dr',
#          'Charlotte, NC 28216',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.34861750185267,
#           'lng': -80.85565277071888}],
#         'lat': 35.34861750185267,
#         'lng': -80.85565277071888,
#         'postalCode': '28216',
#         'state': 'NC'},
#        'name': "Moe's Southwest Grill",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b2bcf30f964a52069bb24e3-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'delivery': {'id': '1111212',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/firehouse-subs-9826-gilead-rd-ste-c102-huntersville/1111212?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1111212'},
#        'id': '4b2bcf30f964a52069bb24e3',
#        'location': {'address': '9826 Gilead Rd, Ste C-102',
#         'cc': 'US',
#         'city': 'Huntersville',
#         'country': 'United States',
#         'distance': 11939,
#         'formattedAddress': ['9826 Gilead Rd, Ste C-102',
#          'Huntersville, NC 28078',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.406105,
#           'lng': -80.864475}],
#         'lat': 35.406105,
#         'lng': -80.864475,
#         'postalCode': '28078',
#         'state': 'NC'},
#        'name': 'Firehouse Subs Gilead Rd.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5951e942851de53388df563b-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '5951e942851de53388df563b',
#        'location': {'address': '14211 Reese Boulevard',
#         'cc': 'US',
#         'city': 'Huntersville',
#         'country': 'United States',
#         'distance': 12138,
#         'formattedAddress': ['14211 Reese Boulevard',
#          'Huntersville, NC 28078',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.407483885595006,
#           'lng': -80.86307286457581}],
#         'lat': 35.407483885595006,
#         'lng': -80.86307286457581,
#         'postalCode': '28078',
#         'state': 'NC'},
#        'name': 'Metro Diner',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
# ...
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4f329e5319836c91c7e957b2-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'delivery': {'id': '1796106',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/bojangles-famous-chickenn-biscuits-5501-josh-birmingham-parkway-charlotte/1796106?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1796106'},
#        'id': '4f329e5319836c91c7e957b2',
#        'location': {'address': '5501 Josh Birmingham Pkwy',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 11178,
#         'formattedAddress': ['5501 Josh Birmingham Pkwy',
#          'Charlotte, NC 28208',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.220563,
#           'lng': -80.943875}],
#         'lat': 35.220563,
#         'lng': -80.943875,
#         'postalCode': '28208',
#         'state': 'NC'},
#        'name': "Bojangles' Famous Chicken 'n Biscuits",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b604777f964a52066dd29e3-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'delivery': {'id': '1312608',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/nikos-grill-4948-airport-center-parkway-charlotte/1312608?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1312608'},
#        'id': '4b604777f964a52066dd29e3',
#        'location': {'address': '4948 Airport Center Pkwy',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 11349,
#         'formattedAddress': ['4948 Airport Center Pkwy',
#          'Charlotte, NC 28208',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22089825609684,
#           'lng': -80.92066545357797}],
#         'lat': 35.22089825609684,
#         'lng': -80.92066545357797,
#         'postalCode': '28208',
#         'state': 'NC'},
#        'name': "Niko's Grill",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-563d064ccd10bb44c2558cac-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '563d064ccd10bb44c2558cac',
#        'location': {'address': '14311 Reese Blvd W',
#         'cc': 'US',
#         'city': 'Huntersville',
#         'country': 'United States',
#         'distance': 12194,
#         'formattedAddress': ['14311 Reese Blvd W',
#          'Huntersville, NC 28078',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.408416177844515,
#           'lng': -80.86355962669504}],
#         'lat': 35.408416177844515,
#         'lng': -80.86355962669504,
#         'postalCode': '28078',
#         'state': 'NC'},
#        'name': "Jimmy John's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-54ff60b3498e94585e3dc474-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'id': '54ff60b3498e94585e3dc474',
#        'location': {'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 10904,
#         'formattedAddress': ['Charlotte, NC', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.223078448980864,
#           'lng': -80.94041105453356}],
#         'lat': 35.223078448980864,
#         'lng': -80.94041105453356,
#         'state': 'NC'},
#        'name': 'Whiskey River',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4dd3e6ddae6009a5122ab3fc-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'id': '4dd3e6ddae6009a5122ab3fc',
#        'location': {'address': '2311 W Sugar Creek Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 13625,
#         'formattedAddress': ['2311 W Sugar Creek Rd',
#          'Charlotte, NC 28262',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.295967,
#           'lng': -80.797662}],
#         'lat': 35.295967,
#         'lng': -80.797662,
#         'postalCode': '28262',
#         'state': 'NC'},
#        'name': 'Chicken King',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4bb330b0715eef3be0ff85bb-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'delivery': {'id': '1470312',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/mr-charles-chicken--fish-3100-statesville-avenue-charlotte/1470312?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470312'},
#        'id': '4bb330b0715eef3be0ff85bb',
#        'location': {'address': '3100 Statesville Ave',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'at Lasalle St & Atando Ave',
#         'distance': 11812,
#         'formattedAddress': ['3100 Statesville Ave (at Lasalle St & Atando Ave)',
#          'Charlotte, NC 28206',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.26163763314775,
#           'lng': -80.83671746603852}],
#         'lat': 35.26163763314775,
#         'lng': -80.83671746603852,
#         'postalCode': '28206',
#         'state': 'NC'},
#        'name': 'Mr. Charles Chicken & Fish',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-56637e1e498ebe13b0fda5d9-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'primary': True,
#          'shortName': 'Snacks'}],
#        'id': '56637e1e498ebe13b0fda5d9',
#        'location': {'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 11179,
#         'formattedAddress': ['Charlotte, NC 28208', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.220559,
#           'lng': -80.943874}],
#         'lat': 35.220559,
#         'lng': -80.943874,
#         'postalCode': '28208',
#         'state': 'NC'},
#        'name': "Auntie Anne's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b9be428f964a520313236e3-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'primary': True,
#          'shortName': 'Burritos'}],
#        'id': '4b9be428f964a520313236e3',
#        'location': {'address': '102 N Statesville Rd',
#         'cc': 'US',
#         'city': 'Huntersville',
#         'country': 'United States',
#         'distance': 13023,
#         'formattedAddress': ['102 N Statesville Rd',
#          'Huntersville, NC 28078',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.41200456766795,
#           'lng': -80.85435858724344}],
#         'lat': 35.41200456766795,
#         'lng': -80.85435858724344,
#         'postalCode': '28078',
#         'state': 'NC'},
#        'name': "Chico's Mexican Grill",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b05863bf964a520665922e3-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'delivery': {'id': '1316975',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/greens-lunch-309-west-4th-street-charlotte/1316975?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1316975'},
#        'id': '4b05863bf964a520665922e3',
#        'location': {'address': '309 W 4th St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 13605,
#         'formattedAddress': ['309 W 4th St',
#          'Charlotte, NC 28202',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22843524013724,
#           'lng': -80.84670158235116}],
#         'lat': 35.22843524013724,
#         'lng': -80.84670158235116,
#         'postalCode': '28202',
#         'state': 'NC'},
#        'name': "Green's Lunch",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4e56dbc114955ace3034d3d8-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'delivery': {'id': '1459042',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/sushi-star-9905-rose-commons-dr-huntersville/1459042?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1459042'},
#        'id': '4e56dbc114955ace3034d3d8',
#        'location': {'cc': 'US',
#         'country': 'United States',
#         'distance': 12245,
#         'formattedAddress': ['North Carolina', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.408563310001995,
#           'lng': -80.86287211430525}],
#         'lat': 35.408563310001995,
#         'lng': -80.86287211430525,
#         'state': 'North Carolina'},
#        'name': 'Sushi Star',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5959b05cf79faa7961113029-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'delivery': {'id': '1465487',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/jersey-mikes-915-s-point-rd-belmont/1465487?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1465487'},
#        'id': '5959b05cf79faa7961113029',
#        'location': {'address': '905 South Point Road, Suite H',
#         'cc': 'US',
#         'city': 'Belmont',
#         'country': 'United States',
#         'distance': 13703,
#         'formattedAddress': ['905 South Point Road, Suite H',
#          'Belmont, NC 28012-9520',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.223842,
#           'lng': -81.037102}],
#         'lat': 35.223842,
#         'lng': -81.037102,
#         'postalCode': '28012-9520',
#         'state': 'NC'},
#        'name': "Jersey Mike's Subs",
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Charlotte',
#   'headerLocation': 'Charlotte',
#   'headerLocationGranularity': 'city',
#   'query': 'food',
#   'suggestedBounds': {'ne': {'lat': 35.44410112312013,
#     'lng': -80.79387453969596},
#    'sw': {'lat': 35.19786087687988, 'lng': -81.09510346030405}},
#   'suggestedFilters': {'filters': [{'key': 'price', 'name': '$-$$$$'},
#     {'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 135}}

# %%
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5e840fec3907e7001b354f1c'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b575d62f964a520c23328e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'id': '4b575d62f964a520c23328e3',
#        'location': {'address': '7508 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 1865,
#         'formattedAddress': ['7508 S Tryon St',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.1503,
#           'lng': -80.925411}],
#         'lat': 35.1503,
#         'lng': -80.925411,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': "Zaxby's Chicken Fingers & Buffalo Wings",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b67195bf964a520683a2be3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'delivery': {'id': '1048698',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/firehouse-subs-8516-s-tryon-st-ste-105-charlotte/1048698?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1048698'},
#        'id': '4b67195bf964a520683a2be3',
#        'location': {'address': '8516 S Tryon St Ste 105',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2765,
#         'formattedAddress': ['8516 S Tryon St Ste 105',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13971,
#           'lng': -80.934993}],
#         'lat': 35.13971,
#         'lng': -80.934993,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Firehouse Subs',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4d6ee1b7516b8cfa270d4910-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'primary': True,
#          'shortName': 'Southern / Soul'}],
#        'delivery': {'id': '1317256',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/nanas-soul-food-kitchen-2908-oak-lake-boulevard-charlotte/1317256?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1317256'},
#        'id': '4d6ee1b7516b8cfa270d4910',
#        'location': {'address': '2908 Oak Lake Blvd Ste 106',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3127,
#         'formattedAddress': ['2908 Oak Lake Blvd Ste 106',
#          'Charlotte, NC 28208',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.19007525647346,
#           'lng': -80.9219026591502}],
#         'lat': 35.19007525647346,
#         'lng': -80.9219026591502,
#         'postalCode': '28208',
#         'state': 'NC'},
#        'name': "Nana's Soul Food Kitchen",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b573c0ef964a5206a2c28e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'delivery': {'id': '1319096',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/siam-garden-3607-whitehall-park-drive-charlotte/1319096?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1319096'},
#        'id': '4b573c0ef964a5206a2c28e3',
#        'location': {'address': '3607 Whitehall Park Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 1930,
#         'formattedAddress': ['3607 Whitehall Park Dr',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.151786037932624,
#           'lng': -80.95060840701278}],
#         'lat': 35.151786037932624,
#         'lng': -80.95060840701278,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Siam Garden',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-56b62e01498e225f839b1467-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '56b62e01498e225f839b1467',
#        'location': {'address': '4847 Shopton Rd Suite A',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2561,
#         'formattedAddress': ['4847 Shopton Rd Suite A',
#          'Charlotte, NC 28278',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.171091254651095,
#           'lng': -80.96320223168911}],
#         'lat': 35.171091254651095,
#         'lng': -80.96320223168911,
#         'postalCode': '28278',
#         'state': 'NC'},
#        'name': 'Highway 55 Burgers, Shakes, & Fries',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b4a95e5f964a5201d8b26e3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'delivery': {'id': '1309336',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/dragon-buffet-8170-south-tryon-street-charlotte/1309336?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1309336'},
#        'id': '4b4a95e5f964a5201d8b26e3',
#        'location': {'address': '8170 S Tryon St #A',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'near Walmart SuperCenter',
#         'distance': 2110,
#         'formattedAddress': ['8170 S Tryon St #A (near Walmart SuperCenter)',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14557647588551,
#           'lng': -80.9364071532107}],
#         'lat': 35.14557647588551,
#         'lng': -80.9364071532107,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Dragon Buffet',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b5d1481f964a520a65129e3-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'id': '4b5d1481f964a520a65129e3',
#        'location': {'address': '2414 Sandy Porter Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'South Tryon',
#         'distance': 3211,
#         'formattedAddress': ['2414 Sandy Porter Rd (South Tryon)',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.135853412426634,
#           'lng': -80.94007396659799}],
#         'lat': 35.135853412426634,
#         'lng': -80.94007396659799,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Mac's Speed Shop",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4bbbc38de436ef3b13cd5564-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'primary': True,
#          'shortName': 'Southern / Soul'}],
#        'delivery': {'id': '1741707',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/lawans-soul-food-restaurant-7520-s-tryon-st-charlotte/1741707?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1741707'},
#        'id': '4bbbc38de436ef3b13cd5564',
#        'location': {'address': '7520 S Tryon St Ste 19',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 1753,
#         'formattedAddress': ['7520 S Tryon St Ste 19',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.15101090818355,
#           'lng': -80.92634195722202}],
#         'lat': 35.15101090818355,
#         'lng': -80.92634195722202,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': "La'Wan's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b1d44aff964a520f10d24e3-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'delivery': {'id': '1247530',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/panera-bread-8152-s-tryon-st-charlotte/1247530?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1247530'},
#        'id': '4b1d44aff964a520f10d24e3',
#        'location': {'address': '8152 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'Highway 49 at I-485',
#         'distance': 2315,
#         'formattedAddress': ['8152 S Tryon St (Highway 49 at I-485)',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.144005,
#           'lng': -80.932129}],
#         'lat': 35.144005,
#         'lng': -80.932129,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Panera Bread',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b55f0a5f964a520b1f727e3-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'delivery': {'id': '1470017',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/luigis-pizza-8170-south-tryon-street-charlotte/1470017?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470017'},
#        'id': '4b55f0a5f964a520b1f727e3',
#        'location': {'address': '8170 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2086,
#         'formattedAddress': ['8170 S Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14578627134498,
#           'lng': -80.93632257223713}],
#         'lat': 35.14578627134498,
#         'lng': -80.93632257223713,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Luigi's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5a5aa606b3d8e2301fa35727-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'id': '5a5aa606b3d8e2301fa35727',
#        'location': {'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3381,
#         'formattedAddress': ['Charlotte, NC 28278', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.168606,
#           'lng': -80.973051}],
#         'lat': 35.168606,
#         'lng': -80.973051,
#         'postalCode': '28278',
#         'state': 'NC'},
#        'name': '37 Sol',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-599f095459fe5c691f9f3b21-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '599f095459fe5c691f9f3b21',
#        'location': {'address': '4830 Berewick Town Center Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'Steele Creek Road',
#         'distance': 3251,
#         'formattedAddress': ['4830 Berewick Town Center Dr (Steele Creek Road)',
#          'Charlotte, NC 28278',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.161652000000004,
#           'lng': -80.971775}],
#         'lat': 35.161652000000004,
#         'lng': -80.971775,
#         'postalCode': '28278',
#         'state': 'NC'},
#        'name': 'Mod Pizza',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '548110086'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4e3b30a41f6e844231c79a50-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'delivery': {'id': '1470691',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/carmellas-pizza-grill-8124-south-tryon-street-charlotte/1470691?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470691'},
#        'id': '4e3b30a41f6e844231c79a50',
#        'location': {'address': '8124 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2179,
#         'formattedAddress': ['8124 S Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14552901636655,
#           'lng': -80.93044670833935}],
#         'lat': 35.14552901636655,
#         'lng': -80.93044670833935,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Carmellas Pizza & Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-50f1e726e4b0ee8fd985db10-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'delivery': {'id': '1321625',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/la-poblanita-mexican-restaurant--candy-store-1925-westinghouse-boulevard-charlotte/1321625?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1321625'},
#        'id': '50f1e726e4b0ee8fd985db10',
#        'location': {'address': '1925 Westinghouse Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 4038,
#         'formattedAddress': ['1925 Westinghouse Blvd',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.12831291255914,
#           'lng': -80.93870758323187}],
#         'lat': 35.12831291255914,
#         'lng': -80.93870758323187,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'La Poblanita Mexican Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-54e37e43498e956b4ad19c09-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'primary': True,
#          'shortName': 'Southern / Soul'}],
#        'delivery': {'id': '1309343',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/piedmont-social-house-2135-ayrsley-town-boulevard-charlotte/1309343?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1309343'},
#        'id': '54e37e43498e956b4ad19c09',
#        'location': {'address': '2135 Ayrsley Town Blvd Ste C',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3001,
#         'formattedAddress': ['2135 Ayrsley Town Blvd Ste C',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.137666746301605,
#           'lng': -80.9334894612188}],
#         'lat': 35.137666746301605,
#         'lng': -80.9334894612188,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Piedmont Social House',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b38f71bf964a5202f5325e3-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4b38f71bf964a5202f5325e3',
#        'location': {'address': '2216 W Arrowood Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'at S Tyron St.',
#         'distance': 2225,
#         'formattedAddress': ['2216 W Arrowood Rd (at S Tyron St.)',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.14689,
#           'lng': -80.92472}],
#         'lat': 35.14689,
#         'lng': -80.92472,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': 'Showmars',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-50bd564ae4b0c7b81bb439d9-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '50bd564ae4b0c7b81bb439d9',
#        'location': {'address': '9640 South Tryon Street, Unit K',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'Westinghouse Blvd',
#         'distance': 4080,
#         'formattedAddress': ['9640 South Tryon Street, Unit K (Westinghouse Blvd)',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.1283,
#           'lng': -80.94301639999998}],
#         'lat': 35.1283,
#         'lng': -80.94301639999998,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Milano's Pizza & Pasta",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b0d9a07f964a520fe4b23e3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'primary': True,
#          'shortName': 'Donuts'}],
#        'id': '4b0d9a07f964a520fe4b23e3',
#        'location': {'address': '9033 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3328,
#         'formattedAddress': ['9033 S Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.134702,
#           'lng': -80.93867}],
#         'lat': 35.134702,
#         'lng': -80.93867,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Dunkin'",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5a8eed75838e5925cf1ea8ca-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'id': '5a8eed75838e5925cf1ea8ca',
#        'location': {'address': '2312 Whitehall Park Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2818,
#         'formattedAddress': ['2312 Whitehall Park Dr',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.139218993775444,
#           'lng': -80.93550541047352}],
#         'lat': 35.139218993775444,
#         'lng': -80.93550541047352,
#         'neighborhood': 'Olde Whitehall',
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Chipotle Mexican Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5a10dd47bfc6d02beae57a26-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'delivery': {'id': '1470613',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/smithfields-5121-trojan-drive-charlotte/1470613?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470613'},
#        'id': '5a10dd47bfc6d02beae57a26',
#        'location': {'address': '5121 Trojan Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3202,
#         'formattedAddress': ['5121 Trojan Dr',
#          'Charlotte, NC 28278',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.16414945979281,
#           'lng': -80.97140898139703}],
#         'lat': 35.16414945979281,
#         'lng': -80.97140898139703,
#         'neighborhood': 'Steele Creek',
#         'postalCode': '28278',
#         'state': 'NC'},
#        'name': 'Smithfield’s Chicken ‘N Barbecue',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5aafed412619ee594e4b98d1-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'id': '5aafed412619ee594e4b98d1',
#        'location': {'address': '3320 D',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2699,
#         'formattedAddress': ['3320 D', 'Charlotte, NC 28217', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.181602,
#           'lng': -80.915146}],
#         'lat': 35.181602,
#         'lng': -80.915146,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': 'Chipotle Mexican Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b05863cf964a5208b5922e3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14c941735',
#          'name': 'Wings Joint',
#          'pluralName': 'Wings Joints',
#          'primary': True,
#          'shortName': 'Wings'}],
#        'delivery': {'id': '1469884',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/wild-wing-cafe-2132-ayrsley-town-blvd-charlotte/1469884?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1469884'},
#        'id': '4b05863cf964a5208b5922e3',
#        'location': {'address': '2132 Ayrsley Town Boulevard,',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'S. Tryon',
#         'distance': 2907,
#         'formattedAddress': ['2132 Ayrsley Town Boulevard, (S. Tryon)',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13844,
#           'lng': -80.934935}],
#         'lat': 35.13844,
#         'lng': -80.934935,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Wild Wing Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4bdb818ac712b71389a763b4-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4bdb818ac712b71389a763b4',
#        'location': {'address': '8943 South Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3127,
#         'formattedAddress': ['8943 South Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.136439,
#           'lng': -80.936751}],
#         'lat': 35.136439,
#         'lng': -80.936751,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Hungry Howie's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b0d737ff964a520954823e3-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'delivery': {'id': '1469558',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/don-pedro-mexican-restaurant-8943-south-tryon-street-charlotte/1469558?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1469558'},
#        'id': '4b0d737ff964a520954823e3',
#        'location': {'address': '8943 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3191,
#         'formattedAddress': ['8943 S Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.135890522992476,
#           'lng': -80.93774734887653}],
#         'lat': 35.135890522992476,
#         'lng': -80.93774734887653,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Don Pedro Mexican Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5a3d1528f0b49021d3bd358c-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '5a3d1528f0b49021d3bd358c',
#        'location': {'address': '3625 City Park Dr',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'W Tyvola Rd',
#         'distance': 2664,
#         'formattedAddress': ['3625 City Park Dr (W Tyvola Rd)',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.181919,
#           'lng': -80.9160902}],
#         'lat': 35.181919,
#         'lng': -80.9160902,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': 'Panera Bread',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-53172b7f498eef7d8980b6b2-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'primary': True,
#          'shortName': 'Breakfast'}],
#        'id': '53172b7f498eef7d8980b6b2',
#        'location': {'address': '2125 W Arrowood Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2366,
#         'formattedAddress': ['2125 W Arrowood Rd',
#          'Charlotte, NC 28217-7937',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.145638,
#           'lng': -80.924297}],
#         'lat': 35.145638,
#         'lng': -80.924297,
#         'postalCode': '28217-7937',
#         'state': 'NC'},
#        'name': 'Waffle House',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b919326f964a520c9c633e3-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '4b919326f964a520c9c633e3',
#        'location': {'address': '2127 Ayrsley Town Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2957,
#         'formattedAddress': ['2127 Ayrsley Town Blvd',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13807103912164,
#           'lng': -80.93331758583938}],
#         'lat': 35.13807103912164,
#         'lng': -80.93331758583938,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Portofino's Ayrsley",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b5bd3a3f964a5207d1829e3-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'id': '4b5bd3a3f964a5207d1829e3',
#        'location': {'address': '4630 Old Pineville Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5359,
#         'formattedAddress': ['4630 Old Pineville Rd',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.17871529456813,
#           'lng': -80.87993434172577}],
#         'lat': 35.17871529456813,
#         'lng': -80.87993434172577,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': "McKoy's Smokehouse & Saloon",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-58d32bb58ab03f3dce466b2c-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '58d32bb58ab03f3dce466b2c',
#        'location': {'address': '4833 - C Berewick Town Center Drive',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3385,
#         'formattedAddress': ['4833 - C Berewick Town Center Drive',
#          'Charlotte, NC 28278-6721',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.161559999999994,
#           'lng': -80.973246}],
#         'lat': 35.161559999999994,
#         'lng': -80.973246,
#         'postalCode': '28278-6721',
#         'state': 'NC'},
#        'name': "Jersey Mike's Subs",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b38fb0ef964a520885325e3-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4b38fb0ef964a520885325e3',
#        'location': {'address': '8032 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2344,
#         'formattedAddress': ['8032 S Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.1442216,
#           'lng': -80.9294046}],
#         'lat': 35.1442216,
#         'lng': -80.9294046,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Chick-fil-A',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-57545bafcd102f916105edaa-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'delivery': {'id': '1310631',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/crispy-banh-mi-5100-south-boulevard-charlotte/1310631?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1310631'},
#        'id': '57545bafcd102f916105edaa',
#        'location': {'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5441,
#         'formattedAddress': ['Charlotte, NC', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.16813953663665,
#           'lng': -80.87658837588354}],
#         'lat': 35.16813953663665,
#         'lng': -80.87658837588354,
#         'state': 'NC'},
#        'name': 'Crispy Banh Mi',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4efcc83aa17cb9e5fcc571be-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '4efcc83aa17cb9e5fcc571be',
#        'location': {'address': '2127 Ayrsley Town Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'S Tryon',
#         'distance': 2922,
#         'formattedAddress': ['2127 Ayrsley Town Blvd (S Tryon)',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.1384153388049,
#           'lng': -80.9330149745504}],
#         'lat': 35.1384153388049,
#         'lng': -80.9330149745504,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Harry's Grille & Tavern",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '38048036'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b099e35f964a520701a23e3-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'delivery': {'id': '1415064',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/vietnam-grille-5615-south-blvd-charlotte/1415064?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1415064'},
#        'id': '4b099e35f964a520701a23e3',
#        'location': {'address': '5615 South Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5514,
#         'formattedAddress': ['5615 South Blvd',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.15988436357615,
#           'lng': -80.87590111777173}],
#         'lat': 35.15988436357615,
#         'lng': -80.87590111777173,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': 'Vietnam Grille',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5200431c498e099388c49b7b-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'primary': True,
#          'shortName': 'Mediterranean'}],
#        'delivery': {'id': '563945',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/jasmine-grill-5033-south-blvd-charlotte/563945?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=563945'},
#        'id': '5200431c498e099388c49b7b',
#        'location': {'address': '5033 South Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'Seneca Pl',
#         'distance': 5538,
#         'formattedAddress': ['5033 South Blvd (Seneca Pl)',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.168549635593095,
#           'lng': -80.87555897245834}],
# ...
#          'primary': True,
#          'shortName': 'Wings'}],
#        'id': '583f96dc91936a36436e0a8a',
#        'location': {'address': '624 Tyvola Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'FACING COSTCO',
#         'distance': 4696,
#         'formattedAddress': ['624 Tyvola Rd (FACING COSTCO)',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.163763,
#           'lng': -80.884628}],
#         'lat': 35.163763,
#         'lng': -80.884628,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': 'Wingstop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b2674cef964a520c37b24e3-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'delivery': {'id': '640610',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/jack-in-the-box-10730-s-tryon-st-charlotte/640610?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=640610'},
#        'id': '4b2674cef964a520c37b24e3',
#        'location': {'address': '10730 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5443,
#         'formattedAddress': ['10730 S Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.11844741215658,
#           'lng': -80.95621883869171}],
#         'lat': 35.11844741215658,
#         'lng': -80.95621883869171,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Jack in the Box',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b68ce35f964a520e78d2be3-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4b68ce35f964a520e78d2be3',
#        'location': {'address': '4426 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5063,
#         'formattedAddress': ['4426 S Tryon St',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.1848,
#           'lng': -80.886411}],
#         'lat': 35.1848,
#         'lng': -80.886411,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': 'Wendy’s',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4e4e081ebd4101d0d7a09f9e-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'delivery': {'id': '988851',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/kfc-9010-s-tryon-st-charlotte/988851?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=988851'},
#        'id': '4e4e081ebd4101d0d7a09f9e',
#        'location': {'address': '9010 South Tryon Street',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3186,
#         'formattedAddress': ['9010 South Tryon Street',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.13599509362517,
#           'lng': -80.93894744850297}],
#         'lat': 35.13599509362517,
#         'lng': -80.93894744850297,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'KFC',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b7b389ff964a520de582fe3-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'delivery': {'id': '1308726',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/johns-family-restaurant-2002-westinghouse-boulevard-charlotte/1308726?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1308726'},
#        'id': '4b7b389ff964a520de582fe3',
#        'location': {'address': '2002 Westinghouse Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 3859,
#         'formattedAddress': ['2002 Westinghouse Blvd',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.129879557710076,
#           'lng': -80.93752998623825}],
#         'lat': 35.129879557710076,
#         'lng': -80.93752998623825,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "John's Family Restaurant",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '449295471'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4bd2ee9c462cb7135527dd07-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '4bd2ee9c462cb7135527dd07',
#        'location': {'address': '225 E Woodlawn Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5247,
#         'formattedAddress': ['225 E Woodlawn Rd',
#          'Charlotte, NC 28217',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.178604726440085,
#           'lng': -80.88118095611227}],
#         'lat': 35.178604726440085,
#         'lng': -80.88118095611227,
#         'postalCode': '28217',
#         'state': 'NC'},
#        'name': 'Carolina Prime Steakhouse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4bf5d0bb9abec9b6fcc824e8-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4bf5d0bb9abec9b6fcc824e8',
#        'location': {'address': '10720 S Tryon St',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 5377,
#         'formattedAddress': ['10720 S Tryon St',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.11935815180113,
#           'lng': -80.95716247718126}],
#         'lat': 35.11935815180113,
#         'lng': -80.95716247718126,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Wang & King Asian Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4b17e4bbf964a52059c923e3-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4b17e4bbf964a52059c923e3',
#        'location': {'address': '10823 John Price Rd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': 'S. Tryon St',
#         'distance': 5422,
#         'formattedAddress': ['10823 John Price Rd (S. Tryon St)',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.119010158866956,
#           'lng': -80.9574144333601}],
#         'lat': 35.119010158866956,
#         'lng': -80.9574144333601,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Cicis',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-4de80f5ad22d09215a136d03-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4de80f5ad22d09215a136d03',
#        'location': {'address': '2215 Ayrsley Town Blvd',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2905,
#         'formattedAddress': ['2215 Ayrsley Town Blvd',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.1384483853436,
#           'lng': -80.93520660662693}],
#         'lat': 35.1384483853436,
#         'lng': -80.93520660662693,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': "Stoney's Woodfired Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-5cfe4f0f2aff31002cbb8af6-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '5cfe4f0f2aff31002cbb8af6',
#        'location': {'address': '2127 Ayrsley Town Blvd Ste 101A',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2957,
#         'formattedAddress': ['2127 Ayrsley Town Blvd Ste 101A',
#          'Charlotte, NC 28273',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.1381,
#           'lng': -80.93299}],
#         'lat': 35.1381,
#         'lng': -80.93299,
#         'postalCode': '28273',
#         'state': 'NC'},
#        'name': 'Famous Toastery Ayrsley',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-56f2ecb4498eb2d412a99274-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'delivery': {'id': '1470998',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/pho-ngon-2215-ayrsley-town-boulevard-charlotte/1470998?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470998'},
#        'id': '56f2ecb4498eb2d412a99274',
#        'location': {'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'distance': 2989,
#         'formattedAddress': ['Charlotte, NC', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.137682414415785,
#           'lng': -80.9355022298776}],
#         'lat': 35.137682414415785,
#         'lng': -80.9355022298776,
#         'state': 'NC'},
#        'name': 'Pho Ngon',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-3-52406bdb498e138596cc0dd9-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'primary': True,
#          'shortName': 'Food Truck'}],
#        'id': '52406bdb498e138596cc0dd9',
#        'location': {'cc': 'US',
#         'city': 'Charlotte',
#         'country': 'United States',
#         'crossStreet': '3rd & Tryon',
#         'distance': 3060,
#         'formattedAddress': ['3rd & Tryon', 'Charlotte, NC', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.137348954475264,
#           'lng': -80.93117171268528}],
#         'lat': 35.137348954475264,
#         'lng': -80.93117171268528,
#         'state': 'NC'},
#        'name': 'Papi Queso Truck',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Charlotte',
#   'headerLocation': 'Charlotte',
#   'headerLocationGranularity': 'city',
#   'query': 'food',
#   'suggestedBounds': {'ne': {'lat': 35.21522105068805,
#     'lng': -80.8743361546236},
#    'sw': {'lat': 35.11384494931195, 'lng': -80.99811184537639}},
#   'suggestedFilters': {'filters': [{'key': 'price', 'name': '$-$$$$'},
#     {'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 113}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                      name  ...        lng
# 0                             Chick-fil-A  ... -80.944759
# 1                    Shuffletown Drive-in  ... -80.952922
# 2                                Heirloom  ... -80.937486
# 3  Freddy's Frozen Custard & Steakburgers  ... -80.943360
# 4                            Tony's Pizza  ... -80.868105
#
# [5 rows x 4 columns]

# %%
venues2 = results2['response']['groups'][0]['items']
    
nearby_venues2 = json_normalize(venues2) # flatten JSON

# filter columns
filtered_columns2 = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues2 =nearby_venues2.loc[:, filtered_columns2]

# filter the category for each row
nearby_venues2['venue.categories'] = nearby_venues2.apply(get_category_type, axis=1)

# clean columns
nearby_venues2.columns = [col.split(".")[-1] for col in nearby_venues2.columns]

nearby_venues2.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                       name  ...        lng
# 0  Zaxby's Chicken Fingers & Buffalo Wings  ... -80.925411
# 1                           Firehouse Subs  ... -80.934993
# 2                 Nana's Soul Food Kitchen  ... -80.921903
# 3                              Siam Garden  ... -80.950608
# 4      Highway 55 Burgers, Shakes, & Fries  ... -80.963202
#
# [5 rows x 4 columns]

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %%
print('{} venues were returned by Foursquare for southwest Charlotte.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare for southwest Charlotte.

# %%
charlotte_map = folium.Map(location=[35.2271, -80.8431], zoom_start=11)

folium.Choropleth(
    geo_data=charlotte_geo,
    data=df_top_charlotte,
    columns=['zipcode', 'Growth'],
    key_on='feature.properties.zipcode',
    fill_color='YlOrRd', 
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Growth in Charlotte",
    highlight=True
).add_to(charlotte_map)

for i in range(0,len(nearby_venues)):
    folium.CircleMarker(([nearby_venues.iloc[i]['lat'], nearby_venues.iloc[i]['lng']]), 
                        popup=nearby_venues.iloc[i]['name'], fill=True, 
                        fill_opacity=.3, 
                        # fill_color=nearby_venues.iloc[i]['Marker Color'], 
                        # color=nearby_venues.iloc[i]['Marker Color']
                        ).add_to(charlotte_map)

for i in range(0,len(nearby_venues2)):
    folium.CircleMarker(([nearby_venues2.iloc[i]['lat'], nearby_venues2.iloc[i]['lng']]), 
                        popup=nearby_venues2.iloc[i]['name'], fill=True, 
                        fill_opacity=.3, 
                        # fill_color=nearby_venues2.iloc[i]['Marker Color'], 
                        # color=nearby_venues2.iloc[i]['Marker Color']
                        ).add_to(charlotte_map)

charlotte_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I ran a second Foursquare query for the southwest portion of the Charlotte area, and it returned the same locations as the other query, even though it had a smaller radius.
